# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahh-sheikhh/voxelmorph/blob/dev/cellular_deformations/train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cell Deformation Estimation with VoxelMorph
#
# 2D deformable registration for PhC-C2DH-U373 cells using VoxelMorph, compared against Horn & Schunck classical optical flow baseline.

# %% [markdown]
# ## 1. Setup

# %%
# %cd /content
![ -d voxelmorph/.git ] || git clone https://github.com/abdullahh-sheikhh/voxelmorph.git
# %cd /content/voxelmorph
# !git checkout dev
# !git pull
# !pip install -e . -q
# !pip install -r cellular_deformations/requirements.txt -q
# !pip install 'numpy<2.1' -q  # avoid scipy/skimage conflict on Colab
# Out:
# /content
# /content/voxelmorph
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1017 bytes | 113.00 KiB/s, done.
# From https://github.com/abdullahh-sheikhh/voxelmorph
#    c40db48..7b16e90  dev        -> origin/dev
# Updating c40db48..7b16e90
# Fast-forward
#  cellular_deformations/train_colab.ipynb | 209 +++++++++-----------------------
#  1 file changed, 58 insertions(+), 151 deletions(-)
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building editable for voxelmorph (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.6 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imagecodecs 2026.5.10 requires numpy>=2.1, but you have numpy 2.0.2 which is incompatible.

# %% [markdown]
# ## 2. Imports
#
# All Python imports for the notebook. Run after section 1.

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap
import torch
from skimage import io
from IPython.display import Image, display

from cellular_deformations.cell_segmentation import SegmentedCellBuilder

print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# PyTorch: 2.10.0+cu128
# CUDA: True
# GPU: Tesla T4

# %% [markdown]
# ## 3. Dataset Download and Setup
#
# PhC-C2DH-U373 training data (sequences 01 and 02) from the Cell Tracking

# %%
# !mkdir -p dataset

if not Path('dataset/train/01').exists():
    print('Downloading training data...')
    # !wget -q https://data.celltrackingchallenge.net/training-datasets/PhC-C2DH-U373.zip -O dataset/train.zip
    # !cd dataset && unzip -q train.zip -d train_raw && mv train_raw/PhC-C2DH-U373/* train/ && rm -rf train_raw train.zip
else:
    print('Training data already exists')

# !echo "Train sequences:" && ls dataset/train/01/ | head -3 && echo "... (115 frames total)"
# Out:
# Training data already exists
# Train sequences:
# t000.tif
# t001.tif
# t002.tif
# ... (115 frames total)

# %% [markdown]
# ## 4. Dataset Visualize

# %%
#  Load two consecutive frames and their Silver Truth masks ─
frame_i, frame_j = 10, 11
seq_dir = Path('dataset/train/01')
st_dir  = Path('dataset/train/01_ST/SEG')

img_i  = io.imread(str(seq_dir / f't{frame_i:03d}.tif')).astype(np.float32) / 255.0
img_j  = io.imread(str(seq_dir / f't{frame_j:03d}.tif')).astype(np.float32) / 255.0
diff   = np.abs(img_j - img_i)

mask_i = io.imread(str(st_dir / f'man_seg{frame_i:03d}.tif')).astype(np.float32)
mask_j = io.imread(str(st_dir / f'man_seg{frame_j:03d}.tif')).astype(np.float32)

binary_i = mask_i > 0
binary_j = mask_j > 0
n_cells  = int(mask_i.max())

# Per-cell colour map: background = black, each cell = distinct colour
cell_cmap = ListedColormap(['black'] + [cm.tab10(i % 10) for i in range(n_cells)])

# Alignment overlay: red = source cells, green = target cells, yellow = overlap
align_rgb         = np.zeros((*img_i.shape, 3), dtype=np.float32)
align_rgb[..., 0] = binary_i.astype(float)
align_rgb[..., 1] = binary_j.astype(float)

#  Figure: 3 rows × 3 panels ─
fig, axes = plt.subplots(3, 3, figsize=(15, 12))

kw_img = dict(cmap='gray', vmin=0, vmax=1)
kw_src = dict(colors=['#00d4ff'], linewidths=0.9, levels=[0.5])   # cyan  = source
kw_tgt = dict(colors=['#ffcc00'], linewidths=0.9, levels=[0.5])   # yellow = target

#  Row 0: single frame anatomy ─
axes[0, 0].imshow(img_i, **kw_img)
axes[0, 0].set_title(
    f'Frame t={frame_i}  —  raw phase-contrast image\n'
    f'696×520 px  |  8-bit grayscale  |  0.65 μm/pixel  |  15 min/frame', fontsize=9)

axes[0, 1].imshow(img_i, **kw_img)
axes[0, 1].contour(binary_i.astype(float), **kw_src)
axes[0, 1].set_title(
    f'Silver Truth cell regions  ({n_cells} cells)\n'
    f'Cyan contours = ST masks  —  used as training supervision', fontsize=9)

axes[0, 2].imshow(mask_i, cmap=cell_cmap, vmin=0, vmax=n_cells, interpolation='nearest')
axes[0, 2].set_title(
    f'Cell label map  (0 = background, 1–{n_cells} = individual cells)\n'
    f'Integer IDs are stable across frames (tracking IDs)', fontsize=9)

#  Row 1: consecutive pair
axes[1, 0].imshow(img_i, **kw_img)
axes[1, 0].contour(binary_i.astype(float), **kw_src)
axes[1, 0].set_title(f'Source frame  t={frame_i}  (cyan = cell boundaries)', fontsize=9)

axes[1, 1].imshow(img_j, **kw_img)
axes[1, 1].contour(binary_j.astype(float), **kw_tgt)
axes[1, 1].set_title(f'Target frame  t={frame_j}  (+15 min)  (yellow = cell boundaries)', fontsize=9)

im = axes[1, 2].imshow(diff, cmap='inferno', vmin=0, vmax=diff.max())
axes[1, 2].set_title('|Target − Source|  —  where intensity changed\nBright = cells moved / deformed', fontsize=9)
fig.colorbar(im, ax=axes[1, 2], fraction=0.046, pad=0.04)

#  Row 2: the registration problem ─
axes[2, 0].imshow(binary_i.astype(float), cmap='gray', vmin=0, vmax=1)
axes[2, 0].set_title(
    f'Source mask  (binary)\n'
    f'Cell area = {binary_i.mean()*100:.1f}% of image pixels', fontsize=9)

axes[2, 1].imshow(binary_j.astype(float), cmap='gray', vmin=0, vmax=1)
axes[2, 1].set_title(
    f'Target mask  (binary)\n'
    f'Cell area = {binary_j.mean()*100:.1f}% of image pixels', fontsize=9)

axes[2, 2].imshow(align_rgb)
axes[2, 2].set_title(
    'Goal: warp source mask → target mask\n'
    'Red = source  |  Green = target  |  Yellow = overlap', fontsize=9)

#  Row labels & final formatting ─
row_labels = ['What the\ndata looks like', 'What we\nregister', 'The alignment\nproblem']
for row, label in enumerate(row_labels):
    axes[row, 0].annotate(
        label, xy=(-0.14, 0.5), xycoords='axes fraction',
        ha='center', va='center', fontsize=8, fontweight='bold',
        rotation=90, color='#444444')

for ax in axes.flat:
    ax.axis('off')

plt.suptitle(
    'PhC-C2DH-U373  —  Glioblastoma-astrocytoma U373 cells  |  Phase-contrast microscopy  |  Seq 01\n'
    '115 frames  ·  228 consecutive pairs  ·  3–8 cells per frame  ·  Silver Truth masks on all frames',
    fontsize=11, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Trainings

# %% [markdown]
# ### 5.1 Masked MSE
#
# Train **Masked MSE** for 200 epochs on sequence 01.
#
# Loss terms:
# - `--mask-weight 1.0` — soft Dice on cell masks (primary alignment signal)
# - `--int-weight 0.1` — cell-restricted intensity loss
# - `--lambda 0.01` — displacement field smoothness regularisation

# %%
# !python -m cellular_deformations.train \
    --data-dir dataset/train \
    --sequences 01 \
    --epochs 200 --batch-size 4 --lr 1e-4 \
    --loss mse --lambda 0.01 \
    --mask-weight 1.0 --int-weight 0.1 \
    --output-dir output/masked_mse \
    --save-every 50
# Out:
# Device: cuda  |  Dataset: 114 pairs  |  Sequences: ['01']  |  Loss: MSE  |  Mode: mask-guided  |  lambda: 0.01
#
# Epochs:   0% 0/200 [00:00<?, ?it/s]Epoch 1/200 — mask_dice_loss: 0.099433
# Epochs:   4% 9/200 [00:44<15:18,  4.81s/it]Epoch 10/200 — mask_dice_loss: 0.097732
# Epochs:  10% 19/200 [01:32<14:55,  4.95s/it]Epoch 20/200 — mask_dice_loss: 0.085674
# Epochs:  14% 29/200 [02:21<13:57,  4.90s/it]Epoch 30/200 — mask_dice_loss: 0.081425
# Epochs:  20% 39/200 [03:11<13:27,  5.02s/it]Epoch 40/200 — mask_dice_loss: 0.072052
# Epochs:  24% 49/200 [04:00<12:30,  4.97s/it]Epoch 50/200 — mask_dice_loss: 0.066303
# Epochs:  30% 59/200 [04:50<11:41,  4.97s/it]Epoch 60/200 — mask_dice_loss: 0.058781
# Epochs:  34% 69/200 [05:39<10:53,  4.99s/it]Epoch 70/200 — mask_dice_loss: 0.054605
# Epochs:  40% 79/200 [06:29<10:00,  4.96s/it]Epoch 80/200 — mask_dice_loss: 0.051720
# Epochs:  44% 89/200 [07:18<09:12,  4.97s/it]Epoch 90/200 — mask_dice_loss: 0.048222
# Epochs:  50% 99/200 [08:08<08:22,  4.97s/it]Epoch 100/200 — mask_dice_loss: 0.046289
# Epochs:  55% 109/200 [08:58<07:40,  5.06s/it]Epoch 110/200 — mask_dice_loss: 0.045648
# Epochs:  60% 119/200 [09:49<06:51,  5.08s/it]Epoch 120/200 — mask_dice_loss: 0.043295
# Epochs:  64% 129/200 [10:39<06:01,  5.10s/it]Epoch 130/200 — mask_dice_loss: 0.042247
# Epochs:  70% 139/200 [11:29<05:08,  5.05s/it]Epoch 140/200 — mask_dice_loss: 0.040785
# Epochs:  74% 149/200 [12:19<04:16,  5.03s/it]Epoch 150/200 — mask_dice_loss: 0.040132
# Epochs:  80% 159/200 [13:09<03:26,  5.03s/it]Epoch 160/200 — mask_dice_loss: 0.039570
# Epochs:  84% 169/200 [13:59<02:35,  5.01s/it]Epoch 170/200 — mask_dice_loss: 0.037092
# Epochs:  90% 179/200 [14:49<01:44,  4.98s/it]Epoch 180/200 — mask_dice_loss: 0.036340
# Epochs:  94% 189/200 [15:38<00:54,  4.98s/it]Epoch 190/200 — mask_dice_loss: 0.035075
# Epochs: 100% 199/200 [16:28<00:04,  4.99s/it]Epoch 200/200 — mask_dice_loss: 0.034413
# Epochs: 100% 200/200 [16:32<00:00,  4.96s/it]
#
# Done. Best mask_dice_loss: 0.034413
# Models and loss curve saved to output/masked_mse/

# %%
display(Image(filename='output/masked_mse/loss_curve.png', width=800))

# %% [markdown]
# ### 5.2 NCC
#
# Train **Normalized Cross-Correlation** for 200 epochs on sequence 01.
#
# Loss terms:
# - `--mask-weight 1.0` — soft Dice on cell masks
# - `--int-weight 0.1` — cell-restricted intensity loss
# - `--lambda 1.0` — displacement field smoothness regularisation

# %%
# !python -m cellular_deformations.train \
    --data-dir dataset/train \
    --sequences 01 \
    --epochs 200 --batch-size 4 --lr 1e-4 \
    --loss ncc --lambda 1.0 \
    --mask-weight 1.0 --int-weight 0.1 \
    --output-dir output/ncc \
    --save-every 50
# Out:
# Device: cuda  |  Dataset: 114 pairs  |  Sequences: ['01']  |  Loss: NCC  |  Mode: mask-guided  |  lambda: 1.0
#
# Epochs:   0% 0/200 [00:00<?, ?it/s]Epoch 1/200 — mask_dice_loss: 0.099350
# Epochs:   4% 9/200 [00:48<16:56,  5.32s/it]Epoch 10/200 — mask_dice_loss: 0.099159
# Epochs:  10% 19/200 [01:40<15:36,  5.17s/it]Epoch 20/200 — mask_dice_loss: 0.087500
# Epochs:  14% 29/200 [02:31<14:37,  5.13s/it]Epoch 30/200 — mask_dice_loss: 0.074045
# Epochs:  20% 39/200 [03:23<13:43,  5.11s/it]Epoch 40/200 — mask_dice_loss: 0.069545
# Epochs:  24% 49/200 [04:14<12:53,  5.12s/it]Epoch 50/200 — mask_dice_loss: 0.065257
# Epochs:  30% 59/200 [05:06<12:10,  5.18s/it]Epoch 60/200 — mask_dice_loss: 0.063129
# Epochs:  34% 69/200 [05:58<11:21,  5.20s/it]Epoch 70/200 — mask_dice_loss: 0.060444
# Epochs:  40% 79/200 [06:49<10:20,  5.13s/it]Epoch 80/200 — mask_dice_loss: 0.058314
# Epochs:  44% 89/200 [07:40<09:30,  5.14s/it]Epoch 90/200 — mask_dice_loss: 0.057253
# Epochs:  50% 99/200 [08:31<08:34,  5.10s/it]Epoch 100/200 — mask_dice_loss: 0.055983
# Epochs:  55% 109/200 [09:23<07:43,  5.09s/it]Epoch 110/200 — mask_dice_loss: 0.054612
# Epochs:  60% 119/200 [10:15<07:08,  5.29s/it]Epoch 120/200 — mask_dice_loss: 0.053439
# Epochs:  64% 129/200 [11:07<06:13,  5.26s/it]Epoch 130/200 — mask_dice_loss: 0.054551
# Epochs:  70% 139/200 [11:59<05:16,  5.19s/it]Epoch 140/200 — mask_dice_loss: 0.051376
# Epochs:  74% 149/200 [12:52<04:25,  5.21s/it]Epoch 150/200 — mask_dice_loss: 0.050550
# Epochs:  80% 159/200 [13:44<03:32,  5.18s/it]Epoch 160/200 — mask_dice_loss: 0.049776
# Epochs:  84% 169/200 [14:36<02:43,  5.28s/it]Epoch 170/200 — mask_dice_loss: 0.049635
# Epochs:  90% 179/200 [15:29<01:50,  5.25s/it]Epoch 180/200 — mask_dice_loss: 0.048933
# Epochs:  94% 189/200 [16:21<00:57,  5.22s/it]Epoch 190/200 — mask_dice_loss: 0.047859
# Epochs: 100% 199/200 [17:13<00:05,  5.19s/it]Epoch 200/200 — mask_dice_loss: 0.047500
# Epochs: 100% 200/200 [17:19<00:00,  5.20s/it]
#
# Done. Best mask_dice_loss: 0.047388
# Models and loss curve saved to output/ncc/

# %%
display(Image(filename='output/ncc/loss_curve.png', width=800))

# %% [markdown]
# ### 5.3 SSIM
#
# Train **SSIM** for 200 epochs on sequence 01.
#
# Loss terms:
# - `--mask-weight 1.0` — soft Dice on cell masks
# - `--int-weight 0.1` — cell-restricted intensity loss
# - `--lambda 1.0` — displacement field smoothness regularisation

# %%
# !python -m cellular_deformations.train \
    --data-dir dataset/train \
    --sequences 01 \
    --epochs 200 --batch-size 4 --lr 1e-4 \
    --loss ssim --lambda 1.0 \
    --mask-weight 1.0 --int-weight 0.1 \
    --output-dir output/ssim \
    --save-every 50
# Out:
# Device: cuda  |  Dataset: 114 pairs  |  Sequences: ['01']  |  Loss: SSIM  |  Mode: mask-guided  |  lambda: 1.0
#
# Epochs:   0% 0/200 [00:00<?, ?it/s]Epoch 1/200 — mask_dice_loss: 0.099624
# Epochs:   4% 9/200 [00:46<16:13,  5.10s/it]Epoch 10/200 — mask_dice_loss: 0.096048
# Epochs:  10% 19/200 [01:37<15:22,  5.10s/it]Epoch 20/200 — mask_dice_loss: 0.083159
# Epochs:  14% 29/200 [02:28<14:36,  5.12s/it]Epoch 30/200 — mask_dice_loss: 0.073616
# Epochs:  20% 39/200 [03:19<13:40,  5.10s/it]Epoch 40/200 — mask_dice_loss: 0.068374
# Epochs:  24% 49/200 [04:11<12:56,  5.14s/it]Epoch 50/200 — mask_dice_loss: 0.064080
# Epochs:  30% 59/200 [05:02<12:12,  5.19s/it]Epoch 60/200 — mask_dice_loss: 0.061510
# Epochs:  34% 69/200 [05:54<11:17,  5.17s/it]Epoch 70/200 — mask_dice_loss: 0.060034
# Epochs:  40% 79/200 [06:45<10:22,  5.15s/it]Epoch 80/200 — mask_dice_loss: 0.059499
# Epochs:  44% 89/200 [07:37<09:31,  5.15s/it]Epoch 90/200 — mask_dice_loss: 0.056867
# Epochs:  50% 99/200 [08:28<08:37,  5.12s/it]Epoch 100/200 — mask_dice_loss: 0.055029
# Epochs:  55% 109/200 [09:20<07:45,  5.11s/it]Epoch 110/200 — mask_dice_loss: 0.053553
# Epochs:  60% 119/200 [10:11<06:57,  5.15s/it]Epoch 120/200 — mask_dice_loss: 0.051953
# Epochs:  64% 129/200 [11:02<06:05,  5.15s/it]Epoch 130/200 — mask_dice_loss: 0.050475
# Epochs:  70% 139/200 [11:54<05:15,  5.17s/it]Epoch 140/200 — mask_dice_loss: 0.048928
# Epochs:  74% 149/200 [12:45<04:21,  5.13s/it]Epoch 150/200 — mask_dice_loss: 0.047485
# Epochs:  80% 159/200 [13:37<03:30,  5.12s/it]Epoch 160/200 — mask_dice_loss: 0.044473
# Epochs:  84% 169/200 [14:28<02:38,  5.12s/it]Epoch 170/200 — mask_dice_loss: 0.041811
# Epochs:  90% 179/200 [15:20<01:48,  5.18s/it]Epoch 180/200 — mask_dice_loss: 0.039501
# Epochs:  94% 187/200 [16:01<01:07,  5.17s/it]

# %%
display(Image(filename='output/ssim/loss_curve.png', width=800))

# %% [markdown]
# ### 5.4 NCC+SSIM
#
# Train **NCC+SSIM** for 200 epochs on sequence 01.
#
# Loss terms:
# - Equal-weight combination of NCC and SSIM intensity losses
# - `--mask-weight 1.0` — soft Dice on cell masks
# - `--int-weight 0.1` — cell-restricted combined intensity loss
# - `--lambda 1.0` — displacement field smoothness regularisation

# %%
# !python -m cellular_deformations.train \
    --data-dir dataset/train \
    --sequences 01 \
    --epochs 200 --batch-size 4 --lr 1e-4 \
    --loss ncc+ssim --lambda 1.0 \
    --mask-weight 1.0 --int-weight 0.1 \
    --output-dir output/ncc_ssim \
    --save-every 50
# Out:
# Done. Models and loss curve saved to output/ncc_ssim/

# %%
display(Image(filename='output/ncc_ssim/loss_curve.png', width=800))

# %% [markdown]
# ### 5.5 MSE+NCC+SSIM
#
# Train **MSE+NCC+SSIM** for 200 epochs on sequence 01.
#
# Loss terms:
# - Equal-weight combination of MSE, NCC, and SSIM intensity losses
# - `--mask-weight 1.0` — soft Dice on cell masks
# - `--int-weight 0.1` — cell-restricted combined intensity loss
# - `--lambda 1.0` — displacement field smoothness regularisation

# %%
# !python -m cellular_deformations.train \
    --data-dir dataset/train \
    --sequences 01 \
    --epochs 200 --batch-size 4 --lr 1e-4 \
    --loss mse+ncc+ssim --lambda 1.0 \
    --mask-weight 1.0 --int-weight 0.1 \
    --output-dir output/mse_ncc_ssim \
    --save-every 50
# Out:
# Done. Models and loss curve saved to output/mse_ncc_ssim/

# %%
display(Image(filename='output/mse_ncc_ssim/loss_curve.png', width=800))

# %% [markdown]
# ## 6. Validations
#
# Evaluate each trained model on held-out sequence 02

# %% [markdown]
# ### 6.1 Masked MSE
#
# Evaluate on held-out sequence 02. Includes Horn & Schunck, Farneback, and TV-L1 baselines.

# %%
# !python -m cellular_deformations.evaluate \
    --model output/masked_mse/best.pt \
    --data-dir dataset/train \
    --gt-dir dataset/train \
    --sequences 02 \
    --output-dir output/eval_masked_mse \
    --max-pairs 0
# Out:
# Device: cuda
# Sequences: ['02']
# Pairs: 114, Baselines: True
#
# Evaluating 114 pairs...
#
#   Pair 0: Dice=0.8688, MaskedMSE=0.007010
#   Pair 1: Dice=0.7990, MaskedMSE=0.008644
#   Pair 2: Dice=0.8350, MaskedMSE=0.009388
#   Pair 3: Dice=0.7297, MaskedMSE=0.007917
#   Pair 4: Dice=0.8530, MaskedMSE=0.006418
#   Pair 5: Dice=0.8763, MaskedMSE=0.006229
#   Pair 6: Dice=0.8296, MaskedMSE=0.005898
#   Pair 7: Dice=0.8666, MaskedMSE=0.005305
#   Pair 8: Dice=0.8534, MaskedMSE=0.006044
#   Pair 9: Dice=0.8550, MaskedMSE=0.006201
#   Pair 10: Dice=0.8012, MaskedMSE=0.005840
#   Pair 11: Dice=0.8381, MaskedMSE=0.006054
#   Pair 12: Dice=0.8580, MaskedMSE=0.006151
#   Pair 13: Dice=0.7349, MaskedMSE=0.007553
#   Pair 14: Dice=0.7750, MaskedMSE=0.008166
#   Pair 15: Dice=0.8537, MaskedMSE=0.006754
#   Pair 16: Dice=0.8830, MaskedMSE=0.006727
#   Pair 17: Dice=0.8415, MaskedMSE=0.006060
#   Pair 18: Dice=0.8778, MaskedMSE=0.006129
#   Pair 19: Dice=0.8744, MaskedMSE=0.006567
#   Pair 20: Dice=0.8605, MaskedMSE=0.006514
#   Pair 21: Dice=0.6732, MaskedMSE=0.008879
#   Pair 22: Dice=0.8177, MaskedMSE=0.009251
#   Pair 23: Dice=0.7024, MaskedMSE=0.008883
#   Pair 24: Dice=0.8586, MaskedMSE=0.007886
#   Pair 25: Dice=0.8582, MaskedMSE=0.008986
#   Pair 26: Dice=0.8534, MaskedMSE=0.009648
#   Pair 27: Dice=0.8622, MaskedMSE=0.009173
#   Pair 28: Dice=0.8621, MaskedMSE=0.008813
#   Pair 29: Dice=0.7633, MaskedMSE=0.011061
#   Pair 30: Dice=0.6615, MaskedMSE=0.008606
#   Pair 31: Dice=0.8156, MaskedMSE=0.007501
#   Pair 32: Dice=0.6533, MaskedMSE=0.009681
#   Pair 33: Dice=0.8238, MaskedMSE=0.009846
#   Pair 34: Dice=0.7847, MaskedMSE=0.010463
#   Pair 35: Dice=0.7285, MaskedMSE=0.010107
#   Pair 36: Dice=0.7955, MaskedMSE=0.012895
#   Pair 37: Dice=0.8388, MaskedMSE=0.011024
#   Pair 38: Dice=0.8396, MaskedMSE=0.010377
#   Pair 39: Dice=0.8611, MaskedMSE=0.010572
#   Pair 40: Dice=0.8392, MaskedMSE=0.009030
#   Pair 41: Dice=0.8623, MaskedMSE=0.009458
#   Pair 42: Dice=0.8133, MaskedMSE=0.010436
#   Pair 43: Dice=0.8417, MaskedMSE=0.011661
#   Pair 44: Dice=0.7830, MaskedMSE=0.014814
#   Pair 45: Dice=0.8528, MaskedMSE=0.011187
#   Pair 46: Dice=0.8312, MaskedMSE=0.008738
#   Pair 47: Dice=0.8775, MaskedMSE=0.010508
#   Pair 48: Dice=0.8207, MaskedMSE=0.009270
#   Pair 49: Dice=0.8074, MaskedMSE=0.012208
#   Pair 50: Dice=0.6361, MaskedMSE=0.011044
#   Pair 51: Dice=0.8097, MaskedMSE=0.007640
#   Pair 52: Dice=0.8279, MaskedMSE=0.010068
#   Pair 53: Dice=0.8290, MaskedMSE=0.009088
#   Pair 54: Dice=0.8302, MaskedMSE=0.007806
#   Pair 55: Dice=0.6329, MaskedMSE=0.012334
#   Pair 56: Dice=0.6607, MaskedMSE=0.009152
#   Pair 57: Dice=0.8217, MaskedMSE=0.009308
#   Pair 58: Dice=0.6827, MaskedMSE=0.009535
#   Pair 59: Dice=0.7621, MaskedMSE=0.010476
#   Pair 60: Dice=0.7993, MaskedMSE=0.010439
#   Pair 61: Dice=0.8285, MaskedMSE=0.010592
#   Pair 62: Dice=0.7426, MaskedMSE=0.010359
#   Pair 63: Dice=0.7504, MaskedMSE=0.010767
#   Pair 64: Dice=0.6927, MaskedMSE=0.009898
#   Pair 65: Dice=0.8312, MaskedMSE=0.010489
#   Pair 66: Dice=0.8380, MaskedMSE=0.009761
#   Pair 67: Dice=0.6828, MaskedMSE=0.009086
#   Pair 68: Dice=0.8557, MaskedMSE=0.008588
#   Pair 69: Dice=0.7610, MaskedMSE=0.010933
#   Pair 70: Dice=0.8481, MaskedMSE=0.007161
#   Pair 71: Dice=0.8602, MaskedMSE=0.007696
#   Pair 72: Dice=0.7096, MaskedMSE=0.006891
#   Pair 73: Dice=0.8807, MaskedMSE=0.006318
#   Pair 74: Dice=0.8798, MaskedMSE=0.006612
#   Pair 75: Dice=0.8800, MaskedMSE=0.008105
#   Pair 76: Dice=0.8494, MaskedMSE=0.008204
#   Pair 77: Dice=0.8896, MaskedMSE=0.007311
#   Pair 78: Dice=0.8863, MaskedMSE=0.006858
#   Pair 79: Dice=0.7232, MaskedMSE=0.007264
#   Pair 80: Dice=0.8577, MaskedMSE=0.007532
#   Pair 81: Dice=0.8420, MaskedMSE=0.009373
#   Pair 82: Dice=0.8087, MaskedMSE=0.011117
#   Pair 83: Dice=0.8893, MaskedMSE=0.006993
#   Pair 84: Dice=0.8327, MaskedMSE=0.007976
#   Pair 85: Dice=0.8562, MaskedMSE=0.008131
#   Pair 86: Dice=0.8580, MaskedMSE=0.007814
#   Pair 87: Dice=0.8640, MaskedMSE=0.007386
#   Pair 88: Dice=0.7407, MaskedMSE=0.006438
#   Pair 89: Dice=0.8486, MaskedMSE=0.006916
#   Pair 90: Dice=0.8602, MaskedMSE=0.007230
#   Pair 91: Dice=0.8757, MaskedMSE=0.006706
#   Pair 92: Dice=0.8803, MaskedMSE=0.006651
#   Pair 93: Dice=0.8689, MaskedMSE=0.007210
#   Pair 94: Dice=0.8520, MaskedMSE=0.007551
#   Pair 95: Dice=0.8800, MaskedMSE=0.007427
#   Pair 96: Dice=0.8810, MaskedMSE=0.007680
#   Pair 97: Dice=0.8816, MaskedMSE=0.008067
#   Pair 98: Dice=0.8468, MaskedMSE=0.010558
#   Pair 99: Dice=0.8492, MaskedMSE=0.008675
#   Pair 100: Dice=0.8717, MaskedMSE=0.008253
#   Pair 101: Dice=0.8646, MaskedMSE=0.008267
#   Pair 102: Dice=0.8600, MaskedMSE=0.009238
#   Pair 103: Dice=0.8273, MaskedMSE=0.008912
#   Pair 104: Dice=0.8641, MaskedMSE=0.009668
#   Pair 105: Dice=0.6782, MaskedMSE=0.008828
#   Pair 106: Dice=0.8637, MaskedMSE=0.009243
#   Pair 107: Dice=0.8470, MaskedMSE=0.010114
#   Pair 108: Dice=0.8472, MaskedMSE=0.008633
#   Pair 109: Dice=0.8457, MaskedMSE=0.008713
#   Pair 110: Dice=0.8455, MaskedMSE=0.010046
#   Pair 111: Dice=0.8488, MaskedMSE=0.010809
#   Pair 112: Dice=0.7726, MaskedMSE=0.011135
#   Pair 113: Dice=0.8267, MaskedMSE=0.008587
#
# --- Results (114 pairs) ---
#   Horn & Schunck: Dice=0.8806 ± 0.0629, MaskedMSE=0.004457 ± 0.001300, Runtime=6.1380s
#   Farneback: Dice=0.8162 ± 0.0657, MaskedMSE=0.008819 ± 0.002019, Runtime=0.1193s
#   TV-L1: Dice=0.8392 ± 0.0630, MaskedMSE=0.008762 ± 0.002019, Runtime=12.2438s
#   VoxelMorph: Dice=0.8190 ± 0.0634, MaskedMSE=0.008686 ± 0.001764, Runtime=0.0128s
#
# Saved to output/eval_masked_mse/

# %%
for img_path in sorted(Path('output/eval_masked_mse').glob('pair_*.png'))[:3]:
    print(img_path.name)
    display(Image(filename=str(img_path), width=900))
# Out:
# pair_0000.png
# pair_0001.png
# pair_0002.png

# %% [markdown]
# ### 6.2 NCC
#
# Evaluate on held-out sequence 02. Baseline numbers reused from section 6.1.

# %%
# !python -m cellular_deformations.evaluate \
    --model output/ncc/best.pt \
    --data-dir dataset/train \
    --gt-dir dataset/train \
    --sequences 02 \
    --output-dir output/eval_ncc \
    --no-baselines \
    --max-pairs 0
# Out:
# Device: cuda
# Sequences: ['02']
# Pairs: 114, Baselines: False
#
# Evaluating 114 pairs...
#
#   Pair 0: Dice=0.9167, MaskedMSE=0.002750
#   Pair 1: Dice=0.8638, MaskedMSE=0.005563
#   Pair 2: Dice=0.8899, MaskedMSE=0.005447
#   Pair 3: Dice=0.7661, MaskedMSE=0.003949
#   Pair 4: Dice=0.8963, MaskedMSE=0.003412
#   Pair 5: Dice=0.9098, MaskedMSE=0.003970
#   Pair 6: Dice=0.9218, MaskedMSE=0.002850
#   Pair 7: Dice=0.9235, MaskedMSE=0.002337
#   Pair 8: Dice=0.9016, MaskedMSE=0.003067
#   Pair 9: Dice=0.9011, MaskedMSE=0.003398
#   Pair 10: Dice=0.9102, MaskedMSE=0.002534
#   Pair 11: Dice=0.9135, MaskedMSE=0.003140
#   Pair 12: Dice=0.9091, MaskedMSE=0.003217
#   Pair 13: Dice=0.7692, MaskedMSE=0.003299
#   Pair 14: Dice=0.8928, MaskedMSE=0.004440
#   Pair 15: Dice=0.8981, MaskedMSE=0.003346
#   Pair 16: Dice=0.9148, MaskedMSE=0.002951
#   Pair 17: Dice=0.9036, MaskedMSE=0.002682
#   Pair 18: Dice=0.9283, MaskedMSE=0.002547
#   Pair 19: Dice=0.9309, MaskedMSE=0.002528
#   Pair 20: Dice=0.8996, MaskedMSE=0.002950
#   Pair 21: Dice=0.7055, MaskedMSE=0.004394
#   Pair 22: Dice=0.8763, MaskedMSE=0.003266
#   Pair 23: Dice=0.7408, MaskedMSE=0.003431
#   Pair 24: Dice=0.8921, MaskedMSE=0.002989
#   Pair 25: Dice=0.9130, MaskedMSE=0.003526
#   Pair 26: Dice=0.9044, MaskedMSE=0.003937
#   Pair 27: Dice=0.9175, MaskedMSE=0.003493
#   Pair 28: Dice=0.9064, MaskedMSE=0.003588
#   Pair 29: Dice=0.7840, MaskedMSE=0.006460
#   Pair 30: Dice=0.7294, MaskedMSE=0.004404
#   Pair 31: Dice=0.8545, MaskedMSE=0.004659
#   Pair 32: Dice=0.7042, MaskedMSE=0.005778
#   Pair 33: Dice=0.8775, MaskedMSE=0.004473
#   Pair 34: Dice=0.8251, MaskedMSE=0.006183
#   Pair 35: Dice=0.8226, MaskedMSE=0.005538
#   Pair 36: Dice=0.8485, MaskedMSE=0.005592
#   Pair 37: Dice=0.8918, MaskedMSE=0.004291
#   Pair 38: Dice=0.8852, MaskedMSE=0.004262
#   Pair 39: Dice=0.8899, MaskedMSE=0.003818
#   Pair 40: Dice=0.8911, MaskedMSE=0.003011
#   Pair 41: Dice=0.9065, MaskedMSE=0.002796
#   Pair 42: Dice=0.8928, MaskedMSE=0.003400
#   Pair 43: Dice=0.8675, MaskedMSE=0.005187
#   Pair 44: Dice=0.8653, MaskedMSE=0.005125
#   Pair 45: Dice=0.9114, MaskedMSE=0.002833
#   Pair 46: Dice=0.9061, MaskedMSE=0.003596
#   Pair 47: Dice=0.9081, MaskedMSE=0.004974
#   Pair 48: Dice=0.8543, MaskedMSE=0.003439
#   Pair 49: Dice=0.8626, MaskedMSE=0.005893
#   Pair 50: Dice=0.6617, MaskedMSE=0.004496
#   Pair 51: Dice=0.8511, MaskedMSE=0.003731
#   Pair 52: Dice=0.8902, MaskedMSE=0.003404
#   Pair 53: Dice=0.8670, MaskedMSE=0.003814
#   Pair 54: Dice=0.8776, MaskedMSE=0.002483
#   Pair 55: Dice=0.6832, MaskedMSE=0.003842
#   Pair 56: Dice=0.7126, MaskedMSE=0.003303
#   Pair 57: Dice=0.8660, MaskedMSE=0.002733
#   Pair 58: Dice=0.7597, MaskedMSE=0.003208
#   Pair 59: Dice=0.8190, MaskedMSE=0.004614
#   Pair 60: Dice=0.8999, MaskedMSE=0.002832
#   Pair 61: Dice=0.8734, MaskedMSE=0.003339
#   Pair 62: Dice=0.8455, MaskedMSE=0.003082
#   Pair 63: Dice=0.7744, MaskedMSE=0.006525
#   Pair 64: Dice=0.7396, MaskedMSE=0.003620
#   Pair 65: Dice=0.8638, MaskedMSE=0.004145
#   Pair 66: Dice=0.9079, MaskedMSE=0.003912
#   Pair 67: Dice=0.7222, MaskedMSE=0.003698
#   Pair 68: Dice=0.9102, MaskedMSE=0.003006
#   Pair 69: Dice=0.8331, MaskedMSE=0.006314
#   Pair 70: Dice=0.8906, MaskedMSE=0.003207
#   Pair 71: Dice=0.9193, MaskedMSE=0.003425
#   Pair 72: Dice=0.7403, MaskedMSE=0.002590
#   Pair 73: Dice=0.9232, MaskedMSE=0.002585
#   Pair 74: Dice=0.9284, MaskedMSE=0.002590
#   Pair 75: Dice=0.9006, MaskedMSE=0.003127
#   Pair 76: Dice=0.8880, MaskedMSE=0.003292
#   Pair 77: Dice=0.9338, MaskedMSE=0.002369
#   Pair 78: Dice=0.9369, MaskedMSE=0.002242
#   Pair 79: Dice=0.7678, MaskedMSE=0.002767
#   Pair 80: Dice=0.9295, MaskedMSE=0.002029
#   Pair 81: Dice=0.9019, MaskedMSE=0.003636
#   Pair 82: Dice=0.8883, MaskedMSE=0.003752
#   Pair 83: Dice=0.9395, MaskedMSE=0.001866
#   Pair 84: Dice=0.8814, MaskedMSE=0.002848
#   Pair 85: Dice=0.9154, MaskedMSE=0.002958
#   Pair 86: Dice=0.9237, MaskedMSE=0.002673
#   Pair 87: Dice=0.9320, MaskedMSE=0.002621
#   Pair 88: Dice=0.7809, MaskedMSE=0.002178
#   Pair 89: Dice=0.9073, MaskedMSE=0.003241
#   Pair 90: Dice=0.9051, MaskedMSE=0.004719
#   Pair 91: Dice=0.9346, MaskedMSE=0.002737
#   Pair 92: Dice=0.9321, MaskedMSE=0.002094
#   Pair 93: Dice=0.9255, MaskedMSE=0.002106
#   Pair 94: Dice=0.8899, MaskedMSE=0.002200
#   Pair 95: Dice=0.9256, MaskedMSE=0.002066
#   Pair 96: Dice=0.9322, MaskedMSE=0.001854
#   Pair 97: Dice=0.9154, MaskedMSE=0.002098
#   Pair 98: Dice=0.8812, MaskedMSE=0.005353
#   Pair 99: Dice=0.9122, MaskedMSE=0.003484
#   Pair 100: Dice=0.9159, MaskedMSE=0.003365
#   Pair 101: Dice=0.9256, MaskedMSE=0.003524
#   Pair 102: Dice=0.9258, MaskedMSE=0.003240
#   Pair 103: Dice=0.8954, MaskedMSE=0.003292
#   Pair 104: Dice=0.9136, MaskedMSE=0.003201
#   Pair 105: Dice=0.7670, MaskedMSE=0.003384
#   Pair 106: Dice=0.8930, MaskedMSE=0.005188
#   Pair 107: Dice=0.9005, MaskedMSE=0.005084
#   Pair 108: Dice=0.9048, MaskedMSE=0.003099
#   Pair 109: Dice=0.9170, MaskedMSE=0.003215
#   Pair 110: Dice=0.9165, MaskedMSE=0.004362
#   Pair 111: Dice=0.9151, MaskedMSE=0.003692
#   Pair 112: Dice=0.8097, MaskedMSE=0.004364
#   Pair 113: Dice=0.8769, MaskedMSE=0.003728
#
# --- Results (114 pairs) ---
#   VoxelMorph: Dice=0.8720 ± 0.0645, MaskedMSE=0.003581 ± 0.001062, Runtime=0.0115s
#
# Saved to output/eval_ncc/

# %%
for img_path in sorted(Path('output/eval_ncc').glob('pair_*.png'))[:3]:
    print(img_path.name)
    display(Image(filename=str(img_path), width=900))
# Out:
# pair_0000.png
# pair_0001.png
# pair_0002.png

# %% [markdown]
# ### 6.3 SSIM
#
# Evaluate on held-out sequence 02. Baseline numbers reused from section 6.1.

# %%
# !python -m cellular_deformations.evaluate \
    --model output/ssim/best.pt \
    --data-dir dataset/train \
    --gt-dir dataset/train \
    --sequences 02 \
    --output-dir output/eval_ssim \
    --no-baselines \
    --max-pairs 0
# Out:
# Device: cuda
# Sequences: ['02']
# Pairs: 114, Baselines: False
#
# Evaluating 114 pairs...
#
#   Pair 0: Dice=0.9098, MaskedMSE=0.002833
#   Pair 1: Dice=0.8580, MaskedMSE=0.005363
#   Pair 2: Dice=0.8707, MaskedMSE=0.005508
#   Pair 3: Dice=0.7594, MaskedMSE=0.005601
#   Pair 4: Dice=0.8894, MaskedMSE=0.004185
#   Pair 5: Dice=0.8994, MaskedMSE=0.004508
#   Pair 6: Dice=0.9126, MaskedMSE=0.004044
#   Pair 7: Dice=0.9114, MaskedMSE=0.003005
#   Pair 8: Dice=0.8928, MaskedMSE=0.003686
#   Pair 9: Dice=0.8942, MaskedMSE=0.004263
#   Pair 10: Dice=0.9015, MaskedMSE=0.004217
#   Pair 11: Dice=0.9025, MaskedMSE=0.004766
#   Pair 12: Dice=0.9003, MaskedMSE=0.004473
#   Pair 13: Dice=0.7592, MaskedMSE=0.004120
#   Pair 14: Dice=0.8831, MaskedMSE=0.005305
#   Pair 15: Dice=0.8909, MaskedMSE=0.004115
#   Pair 16: Dice=0.9127, MaskedMSE=0.003791
#   Pair 17: Dice=0.8944, MaskedMSE=0.003630
#   Pair 18: Dice=0.9190, MaskedMSE=0.002837
#   Pair 19: Dice=0.9253, MaskedMSE=0.002851
#   Pair 20: Dice=0.8820, MaskedMSE=0.003921
#   Pair 21: Dice=0.6906, MaskedMSE=0.004996
#   Pair 22: Dice=0.8629, MaskedMSE=0.003268
#   Pair 23: Dice=0.7356, MaskedMSE=0.003451
#   Pair 24: Dice=0.8751, MaskedMSE=0.003316
#   Pair 25: Dice=0.8863, MaskedMSE=0.003454
#   Pair 26: Dice=0.8894, MaskedMSE=0.003805
#   Pair 27: Dice=0.9083, MaskedMSE=0.003581
#   Pair 28: Dice=0.8999, MaskedMSE=0.003614
#   Pair 29: Dice=0.7810, MaskedMSE=0.007244
#   Pair 30: Dice=0.7307, MaskedMSE=0.005190
#   Pair 31: Dice=0.8368, MaskedMSE=0.004935
#   Pair 32: Dice=0.6938, MaskedMSE=0.005350
#   Pair 33: Dice=0.8731, MaskedMSE=0.004434
#   Pair 34: Dice=0.8281, MaskedMSE=0.005708
#   Pair 35: Dice=0.8176, MaskedMSE=0.005687
#   Pair 36: Dice=0.8417, MaskedMSE=0.005915
#   Pair 37: Dice=0.8841, MaskedMSE=0.005189
#   Pair 38: Dice=0.8822, MaskedMSE=0.004647
#   Pair 39: Dice=0.8818, MaskedMSE=0.004093
#   Pair 40: Dice=0.8827, MaskedMSE=0.003238
#   Pair 41: Dice=0.9102, MaskedMSE=0.003094
#   Pair 42: Dice=0.8884, MaskedMSE=0.003562
#   Pair 43: Dice=0.8560, MaskedMSE=0.004978
#   Pair 44: Dice=0.8524, MaskedMSE=0.005565
#   Pair 45: Dice=0.9095, MaskedMSE=0.003638
#   Pair 46: Dice=0.8944, MaskedMSE=0.004073
#   Pair 47: Dice=0.8995, MaskedMSE=0.004947
#   Pair 48: Dice=0.8456, MaskedMSE=0.003861
#   Pair 49: Dice=0.8511, MaskedMSE=0.005174
#   Pair 50: Dice=0.6672, MaskedMSE=0.005534
#   Pair 51: Dice=0.8424, MaskedMSE=0.003955
#   Pair 52: Dice=0.8885, MaskedMSE=0.003700
#   Pair 53: Dice=0.8621, MaskedMSE=0.003979
#   Pair 54: Dice=0.8742, MaskedMSE=0.002928
#   Pair 55: Dice=0.6838, MaskedMSE=0.004021
#   Pair 56: Dice=0.6999, MaskedMSE=0.003480
#   Pair 57: Dice=0.8606, MaskedMSE=0.003057
#   Pair 58: Dice=0.7550, MaskedMSE=0.003593
#   Pair 59: Dice=0.8096, MaskedMSE=0.004723
#   Pair 60: Dice=0.8960, MaskedMSE=0.003200
#   Pair 61: Dice=0.8601, MaskedMSE=0.004967
#   Pair 62: Dice=0.8385, MaskedMSE=0.004071
#   Pair 63: Dice=0.7674, MaskedMSE=0.006307
#   Pair 64: Dice=0.7348, MaskedMSE=0.003648
#   Pair 65: Dice=0.8612, MaskedMSE=0.004456
#   Pair 66: Dice=0.9034, MaskedMSE=0.003564
#   Pair 67: Dice=0.7147, MaskedMSE=0.003918
#   Pair 68: Dice=0.9109, MaskedMSE=0.003537
#   Pair 69: Dice=0.8118, MaskedMSE=0.006421
#   Pair 70: Dice=0.8825, MaskedMSE=0.003558
#   Pair 71: Dice=0.9161, MaskedMSE=0.003217
#   Pair 72: Dice=0.7357, MaskedMSE=0.002499
#   Pair 73: Dice=0.9210, MaskedMSE=0.002570
#   Pair 74: Dice=0.9284, MaskedMSE=0.002666
#   Pair 75: Dice=0.8996, MaskedMSE=0.003311
#   Pair 76: Dice=0.8807, MaskedMSE=0.003428
#   Pair 77: Dice=0.9294, MaskedMSE=0.002599
#   Pair 78: Dice=0.9263, MaskedMSE=0.002414
#   Pair 79: Dice=0.7646, MaskedMSE=0.002890
#   Pair 80: Dice=0.9258, MaskedMSE=0.002272
#   Pair 81: Dice=0.8960, MaskedMSE=0.003777
#   Pair 82: Dice=0.8845, MaskedMSE=0.004301
#   Pair 83: Dice=0.9348, MaskedMSE=0.002347
#   Pair 84: Dice=0.8757, MaskedMSE=0.003081
#   Pair 85: Dice=0.9071, MaskedMSE=0.003883
#   Pair 86: Dice=0.9151, MaskedMSE=0.003088
#   Pair 87: Dice=0.9271, MaskedMSE=0.003256
#   Pair 88: Dice=0.7752, MaskedMSE=0.002501
#   Pair 89: Dice=0.9003, MaskedMSE=0.003417
#   Pair 90: Dice=0.8984, MaskedMSE=0.004678
#   Pair 91: Dice=0.9259, MaskedMSE=0.002797
#   Pair 92: Dice=0.9230, MaskedMSE=0.002599
#   Pair 93: Dice=0.9165, MaskedMSE=0.002581
#   Pair 94: Dice=0.8826, MaskedMSE=0.002485
#   Pair 95: Dice=0.9209, MaskedMSE=0.002226
#   Pair 96: Dice=0.9263, MaskedMSE=0.002106
#   Pair 97: Dice=0.9031, MaskedMSE=0.002367
#   Pair 98: Dice=0.8590, MaskedMSE=0.005293
#   Pair 99: Dice=0.8959, MaskedMSE=0.003876
#   Pair 100: Dice=0.9070, MaskedMSE=0.003971
#   Pair 101: Dice=0.9151, MaskedMSE=0.003739
#   Pair 102: Dice=0.9224, MaskedMSE=0.003507
#   Pair 103: Dice=0.8987, MaskedMSE=0.003497
#   Pair 104: Dice=0.9068, MaskedMSE=0.003867
#   Pair 105: Dice=0.7610, MaskedMSE=0.003670
#   Pair 106: Dice=0.8833, MaskedMSE=0.005289
#   Pair 107: Dice=0.8955, MaskedMSE=0.003703
#   Pair 108: Dice=0.9060, MaskedMSE=0.003525
#   Pair 109: Dice=0.9024, MaskedMSE=0.003875
#   Pair 110: Dice=0.9036, MaskedMSE=0.003935
#   Pair 111: Dice=0.9014, MaskedMSE=0.003897
#   Pair 112: Dice=0.8117, MaskedMSE=0.005137
#   Pair 113: Dice=0.8665, MaskedMSE=0.004770
#
# --- Results (114 pairs) ---
#   VoxelMorph: Dice=0.8645 ± 0.0639, MaskedMSE=0.003935 ± 0.001017, Runtime=0.0116s
#
# Saved to output/eval_ssim/

# %%
for img_path in sorted(Path('output/eval_ssim').glob('pair_*.png'))[:3]:
    print(img_path.name)
    display(Image(filename=str(img_path), width=900))
# Out:
# pair_0000.png
# pair_0001.png
# pair_0002.png

# %% [markdown]
# ### 6.4 NCC+SSIM
#
# Evaluate on held-out sequence 02. Baseline numbers reused from section 6.1.

# %%
# !python -m cellular_deformations.evaluate \
    --model output/ncc_ssim/best.pt \
    --data-dir dataset/train \
    --gt-dir dataset/train \
    --sequences 02 \
    --output-dir output/eval_ncc_ssim \
    --no-baselines \
    --max-pairs 0
# Out:
# Device: cuda
# Sequences: ['02']
# Pairs: 114, Baselines: False
#
# Evaluating 114 pairs...
#
#   Pair 0: Dice=0.9170, MaskedMSE=0.002424
#   Pair 1: Dice=0.8719, MaskedMSE=0.005240
#   Pair 2: Dice=0.8863, MaskedMSE=0.005371
#   Pair 3: Dice=0.7709, MaskedMSE=0.005964
#   Pair 4: Dice=0.8992, MaskedMSE=0.004077
#   Pair 5: Dice=0.9102, MaskedMSE=0.004367
#   Pair 6: Dice=0.9275, MaskedMSE=0.003730
#   Pair 7: Dice=0.9201, MaskedMSE=0.002779
#   Pair 8: Dice=0.9038, MaskedMSE=0.003427
#   Pair 9: Dice=0.9138, MaskedMSE=0.004035
#   Pair 10: Dice=0.9214, MaskedMSE=0.003790
#   Pair 11: Dice=0.9150, MaskedMSE=0.004475
#   Pair 12: Dice=0.9142, MaskedMSE=0.004132
#   Pair 13: Dice=0.7628, MaskedMSE=0.003684
#   Pair 14: Dice=0.8924, MaskedMSE=0.004885
#   Pair 15: Dice=0.9121, MaskedMSE=0.003579
#   Pair 16: Dice=0.9177, MaskedMSE=0.003299
#   Pair 17: Dice=0.9072, MaskedMSE=0.003218
#   Pair 18: Dice=0.9262, MaskedMSE=0.002595
#   Pair 19: Dice=0.9273, MaskedMSE=0.002593
#   Pair 20: Dice=0.8938, MaskedMSE=0.003739
#   Pair 21: Dice=0.7082, MaskedMSE=0.005165
#   Pair 22: Dice=0.8901, MaskedMSE=0.003170
#   Pair 23: Dice=0.7419, MaskedMSE=0.003405
#   Pair 24: Dice=0.8887, MaskedMSE=0.003103
#   Pair 25: Dice=0.9061, MaskedMSE=0.003405
#   Pair 26: Dice=0.8978, MaskedMSE=0.003952
#   Pair 27: Dice=0.9128, MaskedMSE=0.003415
#   Pair 28: Dice=0.9115, MaskedMSE=0.003552
#   Pair 29: Dice=0.7868, MaskedMSE=0.007097
#   Pair 30: Dice=0.7452, MaskedMSE=0.005332
#   Pair 31: Dice=0.8587, MaskedMSE=0.005150
#   Pair 32: Dice=0.7086, MaskedMSE=0.005598
#   Pair 33: Dice=0.8843, MaskedMSE=0.004860
#   Pair 34: Dice=0.8283, MaskedMSE=0.006122
#   Pair 35: Dice=0.8388, MaskedMSE=0.005620
#   Pair 36: Dice=0.8622, MaskedMSE=0.006413
#   Pair 37: Dice=0.8940, MaskedMSE=0.004945
#   Pair 38: Dice=0.8958, MaskedMSE=0.004824
#   Pair 39: Dice=0.8921, MaskedMSE=0.004126
#   Pair 40: Dice=0.8939, MaskedMSE=0.003233
#   Pair 41: Dice=0.9102, MaskedMSE=0.002899
#   Pair 42: Dice=0.9022, MaskedMSE=0.003354
#   Pair 43: Dice=0.8732, MaskedMSE=0.005165
#   Pair 44: Dice=0.8610, MaskedMSE=0.005465
#   Pair 45: Dice=0.9197, MaskedMSE=0.003486
#   Pair 46: Dice=0.9125, MaskedMSE=0.004250
#   Pair 47: Dice=0.9089, MaskedMSE=0.004939
#   Pair 48: Dice=0.8497, MaskedMSE=0.003696
#   Pair 49: Dice=0.8577, MaskedMSE=0.005111
#   Pair 50: Dice=0.6758, MaskedMSE=0.005284
#   Pair 51: Dice=0.8487, MaskedMSE=0.003899
#   Pair 52: Dice=0.8950, MaskedMSE=0.003754
#   Pair 53: Dice=0.8665, MaskedMSE=0.003715
#   Pair 54: Dice=0.8816, MaskedMSE=0.002672
#   Pair 55: Dice=0.6880, MaskedMSE=0.004141
#   Pair 56: Dice=0.7070, MaskedMSE=0.003298
#   Pair 57: Dice=0.8689, MaskedMSE=0.002850
#   Pair 58: Dice=0.7580, MaskedMSE=0.003730
#   Pair 59: Dice=0.8186, MaskedMSE=0.004882
#   Pair 60: Dice=0.9028, MaskedMSE=0.003403
#   Pair 61: Dice=0.8768, MaskedMSE=0.004510
#   Pair 62: Dice=0.8445, MaskedMSE=0.004232
#   Pair 63: Dice=0.7656, MaskedMSE=0.006575
#   Pair 64: Dice=0.7388, MaskedMSE=0.004148
#   Pair 65: Dice=0.8651, MaskedMSE=0.004204
#   Pair 66: Dice=0.9075, MaskedMSE=0.003547
#   Pair 67: Dice=0.7194, MaskedMSE=0.003678
#   Pair 68: Dice=0.9134, MaskedMSE=0.003136
#   Pair 69: Dice=0.8320, MaskedMSE=0.006132
#   Pair 70: Dice=0.8883, MaskedMSE=0.003196
#   Pair 71: Dice=0.9173, MaskedMSE=0.003063
#   Pair 72: Dice=0.7427, MaskedMSE=0.002422
#   Pair 73: Dice=0.9269, MaskedMSE=0.002417
#   Pair 74: Dice=0.9309, MaskedMSE=0.002557
#   Pair 75: Dice=0.9080, MaskedMSE=0.003228
#   Pair 76: Dice=0.8941, MaskedMSE=0.003445
#   Pair 77: Dice=0.9371, MaskedMSE=0.002536
#   Pair 78: Dice=0.9411, MaskedMSE=0.002214
#   Pair 79: Dice=0.7720, MaskedMSE=0.002762
#   Pair 80: Dice=0.9320, MaskedMSE=0.002169
#   Pair 81: Dice=0.9056, MaskedMSE=0.003908
#   Pair 82: Dice=0.8896, MaskedMSE=0.004252
#   Pair 83: Dice=0.9406, MaskedMSE=0.001998
#   Pair 84: Dice=0.8862, MaskedMSE=0.003150
#   Pair 85: Dice=0.9188, MaskedMSE=0.003583
#   Pair 86: Dice=0.9226, MaskedMSE=0.003092
#   Pair 87: Dice=0.9399, MaskedMSE=0.002879
#   Pair 88: Dice=0.7778, MaskedMSE=0.002342
#   Pair 89: Dice=0.9084, MaskedMSE=0.003480
#   Pair 90: Dice=0.9092, MaskedMSE=0.004317
#   Pair 91: Dice=0.9287, MaskedMSE=0.002554
#   Pair 92: Dice=0.9290, MaskedMSE=0.002278
#   Pair 93: Dice=0.9260, MaskedMSE=0.002234
#   Pair 94: Dice=0.8952, MaskedMSE=0.002473
#   Pair 95: Dice=0.9256, MaskedMSE=0.002123
#   Pair 96: Dice=0.9315, MaskedMSE=0.002097
#   Pair 97: Dice=0.9088, MaskedMSE=0.002313
#   Pair 98: Dice=0.8790, MaskedMSE=0.005876
#   Pair 99: Dice=0.9129, MaskedMSE=0.003785
#   Pair 100: Dice=0.9110, MaskedMSE=0.003444
#   Pair 101: Dice=0.9199, MaskedMSE=0.003582
#   Pair 102: Dice=0.9277, MaskedMSE=0.003380
#   Pair 103: Dice=0.9010, MaskedMSE=0.003612
#   Pair 104: Dice=0.9134, MaskedMSE=0.004163
#   Pair 105: Dice=0.7658, MaskedMSE=0.003672
#   Pair 106: Dice=0.8901, MaskedMSE=0.004662
#   Pair 107: Dice=0.8932, MaskedMSE=0.004321
#   Pair 108: Dice=0.9024, MaskedMSE=0.003445
#   Pair 109: Dice=0.9156, MaskedMSE=0.003558
#   Pair 110: Dice=0.9119, MaskedMSE=0.004092
#   Pair 111: Dice=0.9122, MaskedMSE=0.003908
#   Pair 112: Dice=0.8169, MaskedMSE=0.004645
#   Pair 113: Dice=0.8719, MaskedMSE=0.004357
#
# --- Results (114 pairs) ---
#   VoxelMorph: Dice=0.8737 ± 0.0641, MaskedMSE=0.003839 ± 0.001085, Runtime=0.0114s
#
# Saved to output/eval_ncc_ssim/

# %%
for img_path in sorted(Path('output/eval_ncc_ssim').glob('pair_*.png'))[:3]:
    print(img_path.name)
    display(Image(filename=str(img_path), width=900))
# Out:
# pair_0000.png
# pair_0001.png
# pair_0002.png

# %% [markdown]
# ### 6.5 MSE+NCC+SSIM
#
# Evaluate on held-out sequence 02. Baseline numbers reused from section 6.1.

# %%
# !python -m cellular_deformations.evaluate \
    --model output/mse_ncc_ssim/best.pt \
    --data-dir dataset/train \
    --gt-dir dataset/train \
    --sequences 02 \
    --output-dir output/eval_mse_ncc_ssim \
    --no-baselines \
    --max-pairs 0
# Out:
# Device: cuda
# Sequences: ['02']
# Pairs: 114, Baselines: False
#
# Evaluating 114 pairs...
#
#   Pair 0: Dice=0.9192, MaskedMSE=0.002807
#   Pair 1: Dice=0.8632, MaskedMSE=0.005466
#   Pair 2: Dice=0.8878, MaskedMSE=0.005584
#   Pair 3: Dice=0.7710, MaskedMSE=0.005535
#   Pair 4: Dice=0.8957, MaskedMSE=0.004287
#   Pair 5: Dice=0.9089, MaskedMSE=0.004514
#   Pair 6: Dice=0.9161, MaskedMSE=0.003942
#   Pair 7: Dice=0.9223, MaskedMSE=0.002981
#   Pair 8: Dice=0.9076, MaskedMSE=0.003841
#   Pair 9: Dice=0.9084, MaskedMSE=0.004572
#   Pair 10: Dice=0.9067, MaskedMSE=0.004326
#   Pair 11: Dice=0.9129, MaskedMSE=0.004847
#   Pair 12: Dice=0.9134, MaskedMSE=0.004582
#   Pair 13: Dice=0.7668, MaskedMSE=0.004120
#   Pair 14: Dice=0.8855, MaskedMSE=0.005224
#   Pair 15: Dice=0.8948, MaskedMSE=0.004073
#   Pair 16: Dice=0.9160, MaskedMSE=0.003738
#   Pair 17: Dice=0.9074, MaskedMSE=0.003729
#   Pair 18: Dice=0.9247, MaskedMSE=0.003023
#   Pair 19: Dice=0.9266, MaskedMSE=0.003142
#   Pair 20: Dice=0.8992, MaskedMSE=0.004047
#   Pair 21: Dice=0.7006, MaskedMSE=0.005513
#   Pair 22: Dice=0.8777, MaskedMSE=0.003862
#   Pair 23: Dice=0.7384, MaskedMSE=0.003586
#   Pair 24: Dice=0.8755, MaskedMSE=0.003486
#   Pair 25: Dice=0.9007, MaskedMSE=0.003839
#   Pair 26: Dice=0.8915, MaskedMSE=0.003914
#   Pair 27: Dice=0.9112, MaskedMSE=0.003913
#   Pair 28: Dice=0.9044, MaskedMSE=0.003874
#   Pair 29: Dice=0.7826, MaskedMSE=0.007601
#   Pair 30: Dice=0.7375, MaskedMSE=0.005035
#   Pair 31: Dice=0.8411, MaskedMSE=0.005288
#   Pair 32: Dice=0.6974, MaskedMSE=0.005827
#   Pair 33: Dice=0.8782, MaskedMSE=0.005007
#   Pair 34: Dice=0.8390, MaskedMSE=0.005815
#   Pair 35: Dice=0.8155, MaskedMSE=0.005487
#   Pair 36: Dice=0.8587, MaskedMSE=0.006335
#   Pair 37: Dice=0.8900, MaskedMSE=0.005293
#   Pair 38: Dice=0.8927, MaskedMSE=0.004963
#   Pair 39: Dice=0.8859, MaskedMSE=0.004264
#   Pair 40: Dice=0.8863, MaskedMSE=0.003394
#   Pair 41: Dice=0.9121, MaskedMSE=0.003029
#   Pair 42: Dice=0.8910, MaskedMSE=0.003554
#   Pair 43: Dice=0.8676, MaskedMSE=0.005169
#   Pair 44: Dice=0.8613, MaskedMSE=0.005813
#   Pair 45: Dice=0.9169, MaskedMSE=0.003535
#   Pair 46: Dice=0.8999, MaskedMSE=0.004422
#   Pair 47: Dice=0.9050, MaskedMSE=0.005122
#   Pair 48: Dice=0.8452, MaskedMSE=0.003888
#   Pair 49: Dice=0.8512, MaskedMSE=0.005803
#   Pair 50: Dice=0.6740, MaskedMSE=0.005471
#   Pair 51: Dice=0.8515, MaskedMSE=0.004089
#   Pair 52: Dice=0.8941, MaskedMSE=0.003793
#   Pair 53: Dice=0.8746, MaskedMSE=0.003989
#   Pair 54: Dice=0.8805, MaskedMSE=0.003102
#   Pair 55: Dice=0.6836, MaskedMSE=0.004608
#   Pair 56: Dice=0.7103, MaskedMSE=0.003869
#   Pair 57: Dice=0.8671, MaskedMSE=0.003249
#   Pair 58: Dice=0.7577, MaskedMSE=0.004153
#   Pair 59: Dice=0.8206, MaskedMSE=0.005309
#   Pair 60: Dice=0.8761, MaskedMSE=0.003794
#   Pair 61: Dice=0.8626, MaskedMSE=0.004640
#   Pair 62: Dice=0.8325, MaskedMSE=0.004190
#   Pair 63: Dice=0.7737, MaskedMSE=0.006298
#   Pair 64: Dice=0.7341, MaskedMSE=0.003998
#   Pair 65: Dice=0.8719, MaskedMSE=0.004166
#   Pair 66: Dice=0.9068, MaskedMSE=0.003780
#   Pair 67: Dice=0.7179, MaskedMSE=0.003778
#   Pair 68: Dice=0.9126, MaskedMSE=0.003287
#   Pair 69: Dice=0.8317, MaskedMSE=0.006716
#   Pair 70: Dice=0.8910, MaskedMSE=0.003617
#   Pair 71: Dice=0.9205, MaskedMSE=0.003410
#   Pair 72: Dice=0.7435, MaskedMSE=0.002592
#   Pair 73: Dice=0.9259, MaskedMSE=0.002621
#   Pair 74: Dice=0.9315, MaskedMSE=0.002620
#   Pair 75: Dice=0.9170, MaskedMSE=0.003309
#   Pair 76: Dice=0.8947, MaskedMSE=0.003734
#   Pair 77: Dice=0.9318, MaskedMSE=0.002985
#   Pair 78: Dice=0.9389, MaskedMSE=0.002537
#   Pair 79: Dice=0.7729, MaskedMSE=0.002961
#   Pair 80: Dice=0.9281, MaskedMSE=0.002287
#   Pair 81: Dice=0.9062, MaskedMSE=0.004128
#   Pair 82: Dice=0.8940, MaskedMSE=0.004350
#   Pair 83: Dice=0.9403, MaskedMSE=0.002132
#   Pair 84: Dice=0.8794, MaskedMSE=0.003107
#   Pair 85: Dice=0.9129, MaskedMSE=0.004028
#   Pair 86: Dice=0.9248, MaskedMSE=0.003280
#   Pair 87: Dice=0.9321, MaskedMSE=0.003122
#   Pair 88: Dice=0.7779, MaskedMSE=0.002501
#   Pair 89: Dice=0.9084, MaskedMSE=0.003603
#   Pair 90: Dice=0.9050, MaskedMSE=0.004632
#   Pair 91: Dice=0.9295, MaskedMSE=0.002910
#   Pair 92: Dice=0.9308, MaskedMSE=0.002432
#   Pair 93: Dice=0.9249, MaskedMSE=0.002402
#   Pair 94: Dice=0.8888, MaskedMSE=0.002522
#   Pair 95: Dice=0.9234, MaskedMSE=0.002504
#   Pair 96: Dice=0.9309, MaskedMSE=0.002044
#   Pair 97: Dice=0.9111, MaskedMSE=0.002284
#   Pair 98: Dice=0.8749, MaskedMSE=0.005029
#   Pair 99: Dice=0.9041, MaskedMSE=0.003818
#   Pair 100: Dice=0.9098, MaskedMSE=0.003624
#   Pair 101: Dice=0.9213, MaskedMSE=0.003568
#   Pair 102: Dice=0.9281, MaskedMSE=0.003608
#   Pair 103: Dice=0.9001, MaskedMSE=0.003736
#   Pair 104: Dice=0.9113, MaskedMSE=0.004267
#   Pair 105: Dice=0.7665, MaskedMSE=0.003914
#   Pair 106: Dice=0.8861, MaskedMSE=0.005473
#   Pair 107: Dice=0.8990, MaskedMSE=0.003928
#   Pair 108: Dice=0.9091, MaskedMSE=0.003429
#   Pair 109: Dice=0.9090, MaskedMSE=0.003683
#   Pair 110: Dice=0.9100, MaskedMSE=0.004105
#   Pair 111: Dice=0.9075, MaskedMSE=0.003873
#   Pair 112: Dice=0.8144, MaskedMSE=0.004937
#   Pair 113: Dice=0.8703, MaskedMSE=0.004449
#
# --- Results (114 pairs) ---
#   VoxelMorph: Dice=0.8709 ± 0.0641, MaskedMSE=0.004047 ± 0.001055, Runtime=0.0115s
#
# Saved to output/eval_mse_ncc_ssim/

# %%
for img_path in sorted(Path('output/eval_mse_ncc_ssim').glob('pair_*.png'))[:3]:
    print(img_path.name)
    display(Image(filename=str(img_path), width=900))
# Out:
# pair_0000.png
# pair_0001.png
# pair_0002.png

# %% [markdown]
# ## 7. New Dataset Creation
#
# Extract individual cells from every consecutive frame pair into 224x224 isolated cells (other cells zeroed out)

# %%
builder = SegmentedCellBuilder(
    data_dir="dataset/train",
    output_dir="dataset/segmented_cells",
    crop_size=224,
)
builder.build(sequences=["01", "02"])
# Out:
# Done — 228 pairs processed
#        1437 crops saved to dataset/segmented_cells/
#        0 cells skipped (label missing in one frame)

# %%
crop_dir = Path("dataset/segmented_cells")
crop_files = sorted(crop_dir.glob("*.npz"))
print(f"Total segmented cell crops: {len(crop_files)}")

n_examples = 4
indices = np.linspace(0, len(crop_files) - 1, n_examples, dtype=int)

fig, axes = plt.subplots(n_examples, 4, figsize=(14, 3.5 * n_examples))

for row, idx in enumerate(indices):
    data = np.load(str(crop_files[idx]))
    name = crop_files[idx].stem

    axes[row, 0].imshow(data["source"], cmap="gray")
    axes[row, 0].set_title(f"{name}\nsource", fontsize=10)
    axes[row, 0].axis("off")

    axes[row, 1].imshow(data["target"], cmap="gray")
    axes[row, 1].set_title("target", fontsize=10)
    axes[row, 1].axis("off")

    axes[row, 2].imshow(data["source_mask"], cmap="gray")
    axes[row, 2].set_title("source mask", fontsize=10)
    axes[row, 2].axis("off")

    axes[row, 3].imshow(data["target_mask"], cmap="gray")
    axes[row, 3].set_title("target mask", fontsize=10)
    axes[row, 3].axis("off")

plt.suptitle("Per-Cell Segmented Crops — Sample Inspection", fontsize=14, y=1.0)
plt.tight_layout()
plt.show()
# Out:
# Total segmented cell crops: 1437

# %% [markdown]
# ## 8. New Dataset Training
#
# Train VoxelMorph with NCC+SSIM loss on the segmented cell. Sequence 01 trains, Sequence 02 validates each epoch.

# %%
# !python -m cellular_deformations.train_segmented_cells \
    --data-dir dataset/segmented_cells \
    --epochs 200 \
    --output-dir output/segmented_cells_ncc_ssim

display(Image(filename="output/segmented_cells_ncc_ssim/loss_curve.png"))
# Out:
# Device: cuda  |  Train: 757 crops  |  Val: 680 crops
# Loss: NCC+SSIM  |  lambda_reg: 1.0
#
# Epochs:   0% 0/200 [00:00<?, ?it/s]Epoch 1/200 — train: 0.0043  val: 0.0156
# Epochs:   4% 9/200 [01:13<25:46,  8.10s/it]Epoch 10/200 — train: -0.0499  val: -0.0364
# Epochs:  10% 19/200 [02:31<23:48,  7.89s/it]Epoch 20/200 — train: -0.0557  val: -0.0423
# Epochs:  14% 29/200 [03:49<22:26,  7.87s/it]Epoch 30/200 — train: -0.0630  val: -0.0492
# Epochs:  20% 39/200 [05:08<21:02,  7.84s/it]Epoch 40/200 — train: -0.0722  val: -0.0593
# Epochs:  24% 49/200 [06:28<20:10,  8.02s/it]Epoch 50/200 — train: -0.0816  val: -0.0701
# Epochs:  30% 59/200 [07:46<18:31,  7.88s/it]Epoch 60/200 — train: -0.0848  val: -0.0734
# Epochs:  34% 69/200 [09:05<17:08,  7.85s/it]Epoch 70/200 — train: -0.0863  val: -0.0752
# Epochs:  40% 79/200 [10:23<15:36,  7.74s/it]Epoch 80/200 — train: -0.0876  val: -0.0763
# Epochs:  44% 89/200 [11:43<14:49,  8.01s/it]Epoch 90/200 — train: -0.0885  val: -0.0769
# Epochs:  50% 99/200 [13:01<13:18,  7.91s/it]Epoch 100/200 — train: -0.0891  val: -0.0777
# Epochs:  55% 109/200 [14:20<11:54,  7.85s/it]Epoch 110/200 — train: -0.0898  val: -0.0781
# Epochs:  60% 119/200 [15:38<10:28,  7.76s/it]Epoch 120/200 — train: -0.0905  val: -0.0787
# Epochs:  64% 129/200 [16:57<09:25,  7.97s/it]Epoch 130/200 — train: -0.0910  val: -0.0792
# Epochs:  70% 139/200 [18:16<08:00,  7.88s/it]Epoch 140/200 — train: -0.0917  val: -0.0798
# Epochs:  74% 149/200 [19:34<06:40,  7.86s/it]Epoch 150/200 — train: -0.0920  val: -0.0800
# Epochs:  80% 159/200 [20:53<05:18,  7.77s/it]Epoch 160/200 — train: -0.0924  val: -0.0804
# Epochs:  84% 169/200 [22:12<04:01,  7.78s/it]Epoch 170/200 — train: -0.0926  val: -0.0807
# Epochs:  90% 179/200 [23:31<02:47,  7.98s/it]Epoch 180/200 — train: -0.0929  val: -0.0810
# Epochs:  94% 189/200 [24:49<01:26,  7.86s/it]Epoch 190/200 — train: -0.0930  val: -0.0804
# Epochs: 100% 199/200 [26:07<00:07,  7.80s/it]Epoch 200/200 — train: -0.0932  val: -0.0811
# Epochs: 100% 200/200 [26:16<00:00,  7.88s/it]
#
# Done. Best val loss: -0.0814
# Val Dice: 0.9857 +/- 0.0668
# Metrics and model saved to output/segmented_cells_ncc_ssim/

# %% [markdown]
# ## 9. New Dataset Validations
#
# Evaluate Horn & Schunck, Farneback, and TV-L1 on every cell crop in the sequence-02 validation split. Writes per-baseline Dice and runtime to `output/segmented_cells_baselines/metrics.json`.

# %%
# !python -m cellular_deformations.evaluate_segmented_cells_baselines \
    --data-dir dataset/segmented_cells \
    --val-sequence 02 \
    --output-dir output/segmented_cells_baselines
# Out:
# Validation crops: 680
# Baselines: 100% 680/680 [13:24<00:00,  1.18s/it]
#
# Done. Results:
#   Horn & Schunck  Dice: 0.9227 +/- 0.0968  Runtime: 1.0343 s/crop
#   Farneback       Dice: 0.8099 +/- 0.1319  Runtime: 0.0153 s/crop
#   TV-L1           Dice: 0.9726 +/- 0.0658  Runtime: 0.1243 s/crop
#
# Metrics saved to output/segmented_cells_baselines/metrics.json

# %% [markdown]
# ## 10. Results — Original Dataset
#
# Comparison of classical baselines and VoxelMorph variants on the full-frame 704×544 pairs (held-out sequence 02). All Dice/MSE/runtime numbers are per-pair.

# %%
def load_metrics(path: str, key: str):
    p = Path(path)
    if not p.exists():
        return None
    return json.loads(p.read_text()).get(key)


def fmt(metrics: dict) -> dict:
    dice = (
        f"{metrics['dice_mean']:.4f} ± {metrics['dice_std']:.4f}"
        if 'dice_mean' in metrics else '—'
    )
    mse = (
        f"{metrics['masked_mse_mean']*100:.4f} ± {metrics['masked_mse_std']*100:.4f}"
        if 'masked_mse_mean' in metrics else '—'
    )
    runtime = (
        f"{metrics['runtime_mean']:.4f}"
        if 'runtime_mean' in metrics else '—'
    )
    return {'Dice': dice, 'MSE (x100)': mse, 'Runtime (s)': runtime}


def find_baselines() -> dict | None:
    """Scan all output/eval_*/metrics.json and return the first that has baseline keys."""
    for eval_dir in sorted(Path('output').glob('eval_*')):
        path = eval_dir / 'metrics.json'
        if not path.exists():
            continue
        data = json.loads(path.read_text())
        if any(k in data for k in ('horn_schunck', 'farneback', 'tvl1')):
            return data
    return None


rows = []

baseline_data = find_baselines()
if baseline_data is not None:
    for key, label in [
        ('horn_schunck', 'Horn & Schunck'),
        ('farneback',    'Farneback'),
        ('tvl1',         'TV-L1'),
    ]:
        m = baseline_data.get(key)
        if m:
            rows.append({'Method': label, **fmt(m)})

for name, eval_dir in [
    ('Masked MSE',   'output/eval_masked_mse'),
    ('NCC',          'output/eval_ncc'),
    ('SSIM',         'output/eval_ssim'),
    ('NCC+SSIM',     'output/eval_ncc_ssim'),
    ('MSE+NCC+SSIM', 'output/eval_mse_ncc_ssim'),
]:
    m = load_metrics(f'{eval_dir}/metrics.json', 'vxm')
    if m:
        rows.append({'Method': name, **fmt(m)})

pd.DataFrame(rows).set_index('Method')
# Out:
#                            Dice                  MSE (x100) Runtime (s)
# Method
# Horn & Schunck  0.8806 ± 0.0629  0.4457 ± 0.1300      6.1380
# Farneback       0.8162 ± 0.0657  0.8819 ± 0.2019      0.1193
# TV-L1           0.8392 ± 0.0630  0.8762 ± 0.2019     12.2438
# Masked MSE      0.8190 ± 0.0634  0.8686 ± 0.1764      0.0128
# NCC             0.8720 ± 0.0645  0.3581 ± 0.1062      0.0115
# SSIM            0.8645 ± 0.0639  0.3935 ± 0.1017      0.0116
# NCC+SSIM        0.8737 ± 0.0641  0.3839 ± 0.1085      0.0114
# MSE+NCC+SSIM    0.8709 ± 0.0641  0.4047 ± 0.1055      0.0115

# %% [markdown]
# ## 11. New Dataset Results (Baselines & NCC+SSIM)
#
# Comparison of classical baselines and VoxelMorph (NCC+SSIM) trained on the ~2300 per-cell isolated 224×224 images. Dice / runtime computed per-crop on the held-out sequence-02 cells.

# %%
def _load(path: str, key: str):
    p = Path(path)
    if not p.exists():
        return None
    return json.loads(p.read_text()).get(key)


def _fmt(m: dict) -> dict:
    dice = (
        f"{m['dice_mean']:.4f} ± {m['dice_std']:.4f}"
        if m and 'dice_mean' in m else '—'
    )
    runtime = f"{m['runtime_mean']:.4f}" if m and 'runtime_mean' in m else '—'
    return {'Dice': dice, 'Runtime (s/crop)': runtime}


rows = []

# Baselines on segmented cell crops
baseline_json = 'output/segmented_cells_baselines/metrics.json'
for key, label in [
    ('horn_schunck', 'Horn & Schunck'),
    ('farneback',    'Farneback'),
    ('tvl1',         'TV-L1'),
]:
    m = _load(baseline_json, key)
    if m:
        rows.append({'Method': label, **_fmt(m)})

# VoxelMorph trained on segmented cells
m = _load('output/segmented_cells_ncc_ssim/metrics.json', 'vxm')
if m:
    rows.append({'Method': 'VoxelMorph (NCC+SSIM)', **_fmt(m)})

pd.DataFrame(rows).set_index('Method')
# Out:
#                                   Dice Runtime (s/crop)
# Method
# Horn & Schunck         0.9227 ± 0.0968           1.0343
# Farneback              0.8099 ± 0.1319           0.0153
# TV-L1                  0.9726 ± 0.0658           0.1243
# VoxelMorph (NCC+SSIM)  0.9857 ± 0.0668           0.0013
